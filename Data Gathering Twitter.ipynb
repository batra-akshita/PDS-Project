# %%
#Imports
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import tweepy

# %%
access_token = '977418354402234369-JNjXjPK2tP4j1eGSQBFQjPRGklT7rNy'
access_token_secret = 'NkTisSRGpReMSi5Ne6eoKptWQku1XUpao6ilELPy6e9Aa'
consumer_key = 'Mf9sWyUePbMUJhJmNb70z6FUB'
consumer_secret = '9RO1VrpsAbAgtFzcZBjddPILeG0l6ewCrIuks3hYEoH0moWEXR'

# %%
auth = tweepy.AppAuthHandler(consumer_key, consumer_secret)
auth.secure = True
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
searchQuery = '@UHC'

retweet_filter='-filter:retweets'
q=searchQuery+retweet_filter
tweetsPerQry = 100
sinceId = None

# %%
new_tweets = api.search(q=searchQuery, count=tweetsPerQry)

# %%
print(new_tweets[0].user.screen_name)
print(new_tweets[0].text)
print(new_tweets[0])

# %%
count = 0
for tweet in tweepy.Cursor(api.search, q="@UHC",lang="en", tweet_mode = "extended", truncated = False, since = '2017-03-04').items():
    print(tweet.created_at)

print(count)
# Out:
# 2018-03-24 10:49:04
# 977497521801973760
# 2018-03-24 06:59:24
# 977439721717723141
# 2018-03-24 05:58:24
# 977424371902857216
# 2018-03-24 05:50:57
# 977422497514696704
# 2018-03-24 04:33:06
# 977402905128038400
# 2018-03-24 03:33:49
# 977387985481228288
# 2018-03-24 02:22:11
# 977369959864197122
# 2018-03-24 01:39:26
# 977359199452762112
# 2018-03-24 01:20:41
# 977354481917743105
# 2018-03-24 01:20:21
# 977354397821820928
# 2018-03-24 01:01:46
# 977349720392830976
# 2018-03-24 01:01:35
# 977349675975086081
# 2018-03-24 00:59:32
# 977349157739466752
# 2018-03-24 00:58:54
# 977348999274532864
# 2018-03-24 00:57:55
# 977348754151010304
# 2018-03-24 00:57:51
# 977348735595417600
# 2018-03-24 00:52:01
# 977347266909556737
# 2018-03-24 00:47:30
# 977346133004464129
# 2018-03-24 00:46:04
# 977345770541129728
# 2018-03-24 00:25:12
# 977340517410156544
# 2018-03-23 23:38:19
# 977328719248281600
# 2018-03-23 23:38:00
# 977328638939951104
# 2018-03-23 23:33:15
# 977327446914560000
# ...

# %%
count = 0
for tweet in tweepy.Cursor(api.search, q="@UHC",lang="en", tweet_mode = "extended", truncated = False, max_id = '973875249350574081').items():
    count = count + 1
    if (not tweet.retweeted) and ('RT @' not in tweet.full_text):
        pass
    print(tweet.created_at)

print(count)
# Out:
# 0

# %%
class StdOutListener(StreamListener):

    def on_data(self, data):
        print(data)
        return True

    def on_error(self, status):
        print(status)

# %%
#This handles Twitter authetification and the connection to Twitter Streaming API
l = StdOutListener()
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
stream = Stream(auth, l)

#This line filter Twitter Streams to capture data by the keywords: 'python', 'javascript', 'ruby'
stream.filter(track=["UHC"])
